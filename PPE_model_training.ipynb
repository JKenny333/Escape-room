# %% [markdown]
# <a href="https://colab.research.google.com/github/JKenny333/Escape-room/blob/main/PPE_model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Mar  1 13:45:51 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0              41W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.3/719.3 kB 11.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 205MB/s]
# Ultralytics YOLOv8.1.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 34.0MB/s]
# image 1/1 /content/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 97.0ms
# Speed: 15.4ms preprocess, 97.0ms inference, 781.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # **Custom Data Training**

# %%
# !yolo task=detect mode=train model=yolov8m.pt data='/content/drive/MyDrive/Data Analytics/Projects/PPE detection/Data/Construction/Construction Site Safety/data.yaml' epochs = 50 imgsz = 640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 281MB/s]
# Ultralytics YOLOv8.1.23 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...
